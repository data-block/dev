# %% [markdown]
# https://goo.gl/MQxAgi<br>
# https://goo.gl/cXWxsG<br>
# https://goo.gl/N1Vapv<br>

# %% [markdown]
# ## TKX 피트니스에 오신 것을 환영합니다!
#
# 안녕하세요! TKX 피트니스 데이터분석팀에 오신 것을 환영합니다.
#
# TKX는 국내 최대의 프렌차이즈 피트니스 센터로서, 매월 수 천명에 달하는 신규 회원을 받아 데이터를 분석하고 있습니다.
#
# TKX 피트니스의 장점은 프로그래밍 언어 파이썬(Python)과 데이터 분석 프레임워크 판다스(Pandas)를 활용한 면밀한 데이터 분석입니다. 이 데이터 분석을 바탕으로 KTX의 오퍼레이션 팀 / 코칭 팀은 피트니스 센터에 방문하는 고객 분들, 그리고 방문하지 않는 고객 분들에게도 최선의 맞춤 서비스를 제공해 드리고 있습니다.
#
# 오늘 이 노트북을 받은 분이 해주셔야 하는 일은 2016년도 1월부터 2017년도 12월까지의 신규 가입 고객 데이터를 받아와, 차후에 데이터분석을 더 용이하게 할 수 있도록 데이터를 정리해주는 작업, 일명 데이터 클리닝(Data Cleaning) 작업입니다.
#
# 저희 TKX 피트니스는 언제나 잘 정리되어 있는 고객 정보를 받아서 데이터 분석팀에게 맡길려고 노력하고 있으나, (이 노트북을 받은 분들도 아시겠지만) 현실은 언제나 100% 잘 정리되어있는 데이터를 받아오기가 어렵습니다.
#
# 때문에 이번 시간에는 신규 가입 고객 데이터를 분석하여, 데이터에 몇몇 누락된 부분이나 잘못 기입된 부분 등을 판다스로 정리하고 그 결과를 분석하는 일을 해주셨으면 합니다.
#
# 데이터는 다음의 URL [https://goo.gl/8XGH4T](https://goo.gl/8XGH4T) 에서 다운받을 수 있습니다. 데이터를 다운받아 읽어온 뒤, 하기에 적어놓은 내용대로 데이터를 분석 및 정리를 해주세요.

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_csv('./tkx-user-data.csv')

print(data.shape)
data.head()
# Out:
# (106839, 13)
#     이름  성별           전화번호   나이 현재 체중 목표 체중    키         회원 가입일      회원 정보 갱신일  \
# 0  안원준  남성  010-2292-6251  31세    78    68  176  2016년 07월 05일  2016년 07월 05일
# 1  유세아  여성    01045795881   39  56kg  51kg  172  2016년 10월 02일  2016년 11월 29일
# 2  송솔은  여성  010-7719-8346    0    29    21  167  2017년 09월 06일  2017년 09월 06일
# 3  백서원  여성    01011947169   36    67    65    0  2017년 06월 02일  2017년 07월 28일
# 4  박서은  여성  010-2575-6398   42    60    57  167  2017년 05월 07일  2017년 05월 07일
#
#   흡연 여부 음주 여부 가입 개월 수 개인상담 요청
# 0   아니오  주 1회     0개월     아니요
# 1     예  월 1회     0개월     아니요
# 2     예  주 1회     0개월     아니요
# 3     예  안 마심     0개월     아니요
# 4   아니오  안 마심     0개월       예

# %% [markdown]
# ## 실습

# %% [markdown]
# ** 1. 텍스트로 된 흡연 여부(예/아니오)를 True/False 로 바꾸기 **

# %%
# Write code here!

# %%
data.loc[data["흡연 여부"] == "예", "흡연 여부(bool)"] = True
data.loc[data["흡연 여부"] == "아니오", "흡연 여부(bool)"] = False

print(data.shape)
data[["흡연 여부", "흡연 여부(bool)"]].head()
# Out:
# (106839, 14)
#   흡연 여부 흡연 여부(bool)
# 0   아니오       False
# 1     예        True
# 2     예        True
# 3     예        True
# 4   아니오       False

# %% [markdown]
# ** 2. 나이에서 0세라고 되어있는 것을 NaN으로 바꾸기 **

# %%
# Write code here!

# %%
data["나이"].dtypes
# Out:
# dtype('O')

# %%
import numpy as np

data.loc[data["나이"] == "0", "나이"] = np.nan
print(data.shape)
data.head()
# Out:
# (106839, 14)
#     이름  성별           전화번호   나이 현재 체중 목표 체중    키         회원 가입일      회원 정보 갱신일  \
# 0  안원준  남성  010-2292-6251  31세    78    68  176  2016년 07월 05일  2016년 07월 05일
# 1  유세아  여성    01045795881   39  56kg  51kg  172  2016년 10월 02일  2016년 11월 29일
# 2  송솔은  여성  010-7719-8346  NaN    29    21  167  2017년 09월 06일  2017년 09월 06일
# 3  백서원  여성    01011947169   36    67    65    0  2017년 06월 02일  2017년 07월 28일
# 4  박서은  여성  010-2575-6398   42    60    57  167  2017년 05월 07일  2017년 05월 07일
#
#   흡연 여부 음주 여부 가입 개월 수 개인상담 요청 흡연 여부(bool)
# 0   아니오  주 1회     0개월     아니요       False
# 1     예  월 1회     0개월     아니요        True
# 2     예  주 1회     0개월     아니요        True
# 3     예  안 마심     0개월     아니요        True
# 4   아니오  안 마심     0개월       예       False

# %% [markdown]
# ** 3. 나이 컬럼을 정리하기 **
# - 하나로 통일
# > - oo세
# > - oo

# %% [markdown]
# null은 float 형태니까 아래에서 int(age)로 변경!

# %%
def convert_age_to_integer(age):
    if pd.isnull(age):
        return age
    elif "세" in age:
        age = age.replace("세", "")
    return int(age)

data["나이(int)"] = data["나이"].apply(convert_age_to_integer)

print(data.shape)
data[["나이", "나이(int)"]].head()
# Out:
# (106839, 15)
#     나이  나이(int)
# 0  31세     31.0
# 1   39     39.0
# 2  NaN      NaN
# 3   36     36.0
# 4   42     42.0

# %% [markdown]
# ** 4. 평균(mean) / 최소(min) / 최대(max) 나이 구하기 **

# %%
# Write code here!

# %%
age_mean = data["나이(int)"].mean()
age_min = data["나이(int)"].min()
age_max = data["나이(int)"].max()

print(f"평균 : {age_mean:.1f}%")
print(f"최소 : {age_min:.1f}")
print(f"최대 : {age_max:.1f}")
# Out:
# 평균 : 33.3%
# 최소 : 2.0
# 최대 : 119.0

# %% [markdown]
# ** 5. 컬럼의 순서를 조금 더 직관적으로 바꾸기 **

# %%
# Write code here!

# %% [markdown]
# ## 과제(초급)

# %% [markdown]
# ### 데이터를 사용하기 용이하게 정리하기

# %% [markdown]
# **6. 컬럼 이름 바꾸기**
#
# 보통 프로그래밍을 할 때 한글 컬럼을 사용하면 다양한 문제로 불편을 겪을 때가 많습니다.
#
# 그러므로 컬럼을 전부 한글에서 영어로 바꿔주세요. 컬럼명은 다음과 같이 바꿔주시면 됩니다.
#
# * 이름 - Name
# * 성별 - Gender
# * 전화번호 - Phone Number
# * 나이 - Age
# * 현재 체중 - Current Weight
# * 목표 체종 - Goal Weight
# * 키 - Height
# * 흡연 여부 - Smoking
# * 음주 여부 - Drinking
# * 개인상담 요청 - Request Counselling
# * 회원 가입일 - Joined At
# * 회원 정보 갱신일 - Updated At
# * 가입 개월 수 - Paid Plan

# %%
old_columns = ['이름', '성별', '전화번호', '나이', '현재 체중', '목표 체중', '키', '회원 가입일', '회원 정보 갱신일',
       '흡연 여부', '음주 여부', '가입 개월 수', '개인상담 요청', '흡연 여부(bool)', '나이(int)']
new_columns = ['Name', 'Gender', 'Phone Number', 'Age', 'Current Weight', 'Goal Weight', 'Height','Joined At', 'Updated At',
           'Smoking', 'Drinking', 'Paid Plan', 'Request Counselling', 'Smoke(bool)', 'Age(int)']

data.rename(columns=dict(zip(old_columns, new_columns)), inplace=True)

# %%
data.head()
# Out:
#   Name Gender   Phone Number  Age Current Weight Goal Weight Height  \
# 0  안원준     남성  010-2292-6251  31세             78          68    176
# 1  유세아     여성    01045795881   39           56kg        51kg    172
# 2  송솔은     여성  010-7719-8346  NaN             29          21    167
# 3  백서원     여성    01011947169   36             67          65      0
# 4  박서은     여성  010-2575-6398   42             60          57    167
#
#        Joined At     Updated At Smoking Drinking Paid Plan  \
# 0  2016년 07월 05일  2016년 07월 05일     아니오     주 1회       0개월
# 1  2016년 10월 02일  2016년 11월 29일       예     월 1회       0개월
# 2  2017년 09월 06일  2017년 09월 06일       예     주 1회       0개월
# 3  2017년 06월 02일  2017년 07월 28일       예     안 마심       0개월
# 4  2017년 05월 07일  2017년 05월 07일     아니오     안 마심       0개월
#
#   Request Counselling Smoke(bool)  Age(int)
# 0                 아니요       False      31.0
# 1                 아니요        True      39.0
# 2                 아니요        True       NaN
# 3                 아니요        True      36.0
# 4                   예       False      42.0

# %% [markdown]
# ** 7. '상담 요청' 컬럼을 예/아니오 에서 True/False로 바꿔주세요 **

# %%
# Write code here!

# %%
data.loc[data["Request Counselling"] == "예", "Request Counselling"] = True
data.loc[data["Request Counselling"] == "아니요", "Request Counselling"] = False

print(data.shape)
data.head()
# Out:
# (106839, 15)
#   Name Gender   Phone Number  Age Current Weight Goal Weight Height  \
# 0  안원준     남성  010-2292-6251  31세             78          68    176
# 1  유세아     여성    01045795881   39           56kg        51kg    172
# 2  송솔은     여성  010-7719-8346  NaN             29          21    167
# 3  백서원     여성    01011947169   36             67          65      0
# 4  박서은     여성  010-2575-6398   42             60          57    167
#
#        Joined At     Updated At Smoking Drinking Paid Plan  \
# 0  2016년 07월 05일  2016년 07월 05일     아니오     주 1회       0개월
# 1  2016년 10월 02일  2016년 11월 29일       예     월 1회       0개월
# 2  2017년 09월 06일  2017년 09월 06일       예     주 1회       0개월
# 3  2017년 06월 02일  2017년 07월 28일       예     안 마심       0개월
# 4  2017년 05월 07일  2017년 05월 07일     아니오     안 마심       0개월
#
#    Request Counselling Smoke(bool)  Age(int)
# 0                False       False      31.0
# 1                False        True      39.0
# 2                False        True       NaN
# 3                False        True      36.0
# 4                 True       False      42.0

# %%
data['Request Counselling'].value_counts()
# Out:
# False    96260
# True     10579
# Name: Request Counselling, dtype: int64

# %% [markdown]
# **8. '가입 개월 수' 컬럼을 분석해서, 무료(0개월)인 경우를 True로, 유료인 경우(3, 6, 9, 12개월)를 False로 보여주는 새로운 컬럼을 만들어주세요.**

# %%
# Write code here!

# %%
data['Paid Plan'].dtypes
# Out:
# dtype('O')

# %%
data.loc[data["Paid Plan"] == '0개월', "Paid Plan"] = True
data.loc[data["Paid Plan"] != '0개월', "Paid Plan"] = data["Paid Plan"]

print(data.shape)
data.head(10)
# Out:
# (106839, 15)
#   Name  Gender   Phone Number  Age Current Weight Goal Weight Height  \
# 0  안원준      남성  010-2292-6251  31세             78          68    176
# 1  유세아      여성    01045795881   39           56kg        51kg    172
# 2  송솔은      여성  010-7719-8346  NaN             29          21    167
# 3  백서원      여성    01011947169   36             67          65      0
# 4  박서은      여성  010-2575-6398   42             60          57    167
# 5  전재성      남성  010-7299-1288   39             76          73    171
# 6  유수애      여성  010-2132-4484  NaN              0           0    177
# 7  허태연    Male    01019249265   32          83 kg       78 kg      0
# 8  윤소현  female    01045337615   27             60          58      0
# 9  황윤일    male    01036423916   29             76          70    171
#
#        Joined At     Updated At Smoking Drinking Paid Plan  \
# 0  2016년 07월 05일  2016년 07월 05일     아니오     주 1회      True
# 1  2016년 10월 02일  2016년 11월 29일       예     월 1회      True
# 2  2017년 09월 06일  2017년 09월 06일       예     주 1회      True
# 3  2017년 06월 02일  2017년 07월 28일       예     안 마심      True
# 4  2017년 05월 07일  2017년 05월 07일     아니오     안 마심      True
# 5  2017년 12월 01일  2018년 03월 05일     아니오     월 1회       3개월
# 6  2016년 12월 05일  2016년 12월 05일     아니오     월 2회      12개월
# 7  2016년 10월 25일  2016년 12월 01일     아니오     월 2회      True
# 8  2017년 08월 24일  2017년 09월 02일     아니오     월 2회      True
# 9  2017년 11월 04일  2017년 12월 11일     아니오     월 1회       3개월
#
#    Request Counselling Smoke(bool)  Age(int)
# 0                False       False      31.0
# 1                False        True      39.0
# 2                False        True       NaN
# 3                False        True      36.0
# 4                 True       False      42.0
# 5                False       False      39.0
# 6                False       False       NaN
# 7                False       False      32.0
# 8                False       False      27.0
# 9                False       False      29.0

# %% [markdown]
# ### 컬럼의 형태를 하나로 통일하고, 빈 값이나 outlier들을 NaN으로 바꾸기

# %% [markdown]
# ** 9. 전화번호 컬럼을 정리해주세요. 다음과 같이 정리해주시면 됩니다. **
#   * unknown 이라고 표시되어 있는 전화번호는 빈 전화번호입니다. 이를 NaN으로 바꿔주세요.

# %%
# Write code here!

# %%
import numpy as np

data.loc[data["Phone Number"] == "unknown", "Phone Number"] = np.nan

print(data.shape)
data.head(30)
# Out:
# (106839, 15)
#    Name  Gender   Phone Number   Age Current Weight Goal Weight  Height  \
# 0   안원준      남성  010-2292-6251   31세             78          68     176
# 1   유세아      여성    01045795881    39           56kg        51kg     172
# 2   송솔은      여성  010-7719-8346   NaN             29          21     167
# 3   백서원      여성    01011947169    36             67          65       0
# 4   박서은      여성  010-2575-6398    42             60          57     167
# 5   전재성      남성  010-7299-1288    39             76          73     171
# 6   유수애      여성  010-2132-4484   NaN              0           0     177
# 7   허태연    Male    01019249265    32          83 kg       78 kg       0
# 26  2016년 03월 24일  2016년 04월 04일     아니오     월 2회      True
# 27  2016년 05월 20일  2016년 05월 20일     아니오     월 1회      12개월
# 28  2016년 09월 21일  2016년 09월 21일     아니오     월 2회       6개월
# 29  2016년 03월 01일  2016년 03월 01일     아니오     주 1회      True
#
#     Request Counselling Smoke(bool)  Age(int)
# 0                 False       False      31.0
# 1                 False        True      39.0
# 2                 False        True       NaN
# 3                 False        True      36.0
# 4                  True       False      42.0
# 5                 False       False      39.0
# 6                 False       False       NaN
# 7                 False       False      32.0
# 8                 False       False      27.0
# 9                 False       False      29.0
# 10                False       False      37.0
# 11                False       False      32.0
# 12                False        True      37.0
# 13                False       False      36.0
# 14                False       False      34.0
# 15                 True       False      40.0
# 16                False       False      34.0
# 17                False       False      33.0
# 18                False        True      37.0
# 19                False       False      35.0
# 20                False       False      34.0
# 21                False       False      30.0
# 22                False       False      42.0
# 23                False       False      28.0
# 24                False       False      34.0
# 25                False       False      50.0
# 26                False       False      43.0
# 27                False       False      31.0
# 28                False       False      34.0
# 29                False       False      31.0

# %% [markdown]
# ** 10. 키(cm) 컬럼을 정리해주세요. 다음과 같이 정리해주시면 됩니다.**
#
# * 다양한 형태로 표현되어 있는 키 컬럼(?, ?cm, ? cm 등)을 숫자로 통일해주세요.
# * 키가 0으로 되어있으면 NaN으로 바꿔주세요.
# * 키가 너무 작거나(140cm 이하) 너무 크면(210cm 이상) 마찬가지로 NaN으로 바꿔주세요.

# %%
# Write code here!

# %%
def reshape_height(height):
    if pd.isnull(height):
        return height
    elif "cm" in height:
        height = height.replace("cm", "")
    
    return height
    
data["Height"] = data["Height"].apply(reshape_height)

print(data.shape)
data.head()
# Out:
# (106839, 15)
#   Name Gender   Phone Number  Age Current Weight Goal Weight Height  \
# 0  안원준     남성  010-2292-6251  31세             78          68    176
# 1  유세아     여성    01045795881   39           56kg        51kg    172
# 2  송솔은     여성  010-7719-8346  NaN             29          21    167
# 3  백서원     여성    01011947169   36             67          65      0
# 4  박서은     여성  010-2575-6398   42             60          57    167
#
#        Joined At     Updated At Smoking Drinking Paid Plan  \
# 0  2016년 07월 05일  2016년 07월 05일     아니오     주 1회      True
# 1  2016년 10월 02일  2016년 11월 29일       예     월 1회      True
# 2  2017년 09월 06일  2017년 09월 06일       예     주 1회      True
# 3  2017년 06월 02일  2017년 07월 28일       예     안 마심      True
# 4  2017년 05월 07일  2017년 05월 07일     아니오     안 마심      True
#
#    Request Counselling Smoke(bool)  Age(int)
# 0                False       False      31.0
# 1                False        True      39.0
# 2                False        True       NaN
# 3                False        True      36.0
# 4                 True       False      42.0

# %% [markdown]
# ** 11.'현재 체중'과	'목표 체중' 컬럼을 정리해주세요. 다음과 같이 정리해주시면 됩니다.**
#
# * 다양한 형태로 표현되어 있는 몸무게 컬럼(?, ?kg, ? kg 등)을 숫자로 통일해주세요.
# * 몸무게가 0으로 되어있으면 NaN으로 바꿔주세요.
# * 몸무게가 너무 작거나(40kg 이하) 너무 크면(150kg 이상) 마찬가지로 NaN으로 바꿔주세요.

# %%
# Write code here!

# %%
data.head()
# Out:
#   Name Gender   Phone Number  Age Current Weight Goal Weight Height  \
# 0  안원준     남성  010-2292-6251  31세             78          68    176
# 1  유세아     여성    01045795881   39           56kg        51kg    172
# 2  송솔은     여성  010-7719-8346  NaN             29          21    167
# 3  백서원     여성    01011947169   36             67          65      0
# 4  박서은     여성  010-2575-6398   42             60          57    167
#
#        Joined At     Updated At Smoking Drinking Paid Plan  \
# 0  2016년 07월 05일  2016년 07월 05일     아니오     주 1회      True
# 1  2016년 10월 02일  2016년 11월 29일       예     월 1회      True
# 2  2017년 09월 06일  2017년 09월 06일       예     주 1회      True
# 3  2017년 06월 02일  2017년 07월 28일       예     안 마심      True
# 4  2017년 05월 07일  2017년 05월 07일     아니오     안 마심      True
#
#    Request Counselling Smoke(bool)  Age(int)
# 0                False       False      31.0
# 1                False        True      39.0
# 2                False        True       NaN
# 3                False        True      36.0
# 4                 True       False      42.0

# %%
print(data["Current Weight"].dtypes)
print(data["Goal Weight"].dtypes)
# Out:
# object
# object

# %%
def reshape_weight(weight):
    if pd.isnull(weight):
        return weight
    elif weight == 0:
        weight = np.nan
    elif "kg" in weight:
        weight = int(weight.replace("kg", ""))
    elif 40 >= int(weight) or int(weight) >= 150:
        weight = np.nan
    return weight

data["Current Weight"] = data["Current Weight"].apply(reshape_weight)
data["Goal Weight"] = data["Goal Weight"].apply(reshape_weight)

print(data.shape)
data.head(30)
# Out:
# (106839, 15)
#    Name  Gender   Phone Number   Age Current Weight Goal Weight Height  \
# 0   안원준      남성  010-2292-6251   31세             78          68    176
# 1   유세아      여성    01045795881    39             56          51    172
# 2   송솔은      여성  010-7719-8346   NaN            NaN         NaN    167
# 3   백서원      여성    01011947169    36             67          65      0
# 4   박서은      여성  010-2575-6398    42             60          57    167
# 5   전재성      남성  010-7299-1288    39             76          73    171
# 6   유수애      여성  010-2132-4484   NaN            NaN         NaN    177
# 7   허태연    Male    01019249265    32             83          78      0
# 8   윤소현  female    01045337615    27             60          58      0
# 9   황윤일    male    01036423916    29             76          70    171
# 10  한대권      남성            NaN    37             78          69      0
# 11  장소윤       여    01067892811    32             60          50    164
# 12  서재혁      남성  010-5798-1225   37세             84          82    171
# 13  배윤우    Male  010-3383-4227    36             80          77      0
# 14  권초연      여성  010-6545-3677    34            NaN         NaN    170
# 15  오은규    Male    01096427616    40             80          72    178
# 16  황서은      여성            NaN    34             59          56    172
# 17  홍준후       남    01067151438  33 세             81          74    182
# 18  허예준      남성    01073912817    37             82          75    184
# 19  문승준    male  010-8219-6712    35             80          79   217
# 20  이지빈      여성    01034757279    34             62          55    159
# 21  손승원      남성    01048722115    30            NaN         NaN    169
# 22  정재빈      남성  010-2722-4478    42             81          80    175
# 23  조채윤      여성  010-9154-4311    28             59          57    164
# 24  최수훈    Male  010-8356-8853    34             77          76    176
# 25  안설윤       여  010-2774-3996    50             55          48      0
# 26  이도훈    male    01041543675    43             75          68    173
# 27  서서혜  Female    01013498816    31             62          57      0
# 28  박성원      남성            NaN    34            NaN         NaN      0
# 29  임영준      남성  010-2899-4995    31             81          74    121
#
#         Joined At     Updated At Smoking Drinking Paid Plan  \
400167178175181167173164184176163 17617016417616701702121751731741811711651811751781751691821761831711781650170017316818101671651641651830174172172169168171181182178171176018016217201661761821651711750178019117417818015717417315701790178187183176169230179172170 1740173173175 16517916900167 1751771701771591741701731611761770169163174 166164168170180169178 16716917816217517616717416401730174171170158173001641701840165179172180179176168174173169 174178178171184016800174161175166171 170179168169 1731551770172 178175174167169182177 0169170170017317016417016123816616817417517817018218201720169166177169173177169167178 179172164165162168169167173160167175169 1791821782181720181168174170159 1871670167173163 0178164169178181172172181017217117201191721721621681731680168 179170 180172175166164170177171181166176185173173173163 172169165174 165165016917417517116 ...

# %%
# Write code here!

# %% [markdown]
# ** 13. 전체 데이터에서 흡연자와 비흡연자 인원의 총합을 찾아주세요. **

# %%
data.head()
# Out:
#     이름  성별           전화번호   나이 현재 체중 목표 체중    키         회원 가입일      회원 정보 갱신일  \
# 0  안원준  남성  010-2292-6251  31세    78    68  176  2016년 07월 05일  2016년 07월 05일
# 1  유세아  여성    01045795881   39    56    51  172  2016년 10월 02일  2016년 11월 29일
# 2  송솔은  여성  010-7719-8346  NaN   NaN   NaN  167  2017년 09월 06일  2017년 09월 06일
# 3  백서원  여성    01011947169   36    67    65    0  2017년 06월 02일  2017년 07월 28일
# 4  박서은  여성  010-2575-6398   42    60    57  167  2017년 05월 07일  2017년 05월 07일
#
#   흡연 여부 음주 여부 가입 개월 수  개인상담 요청 흡연 여부(bool)  나이(int)
# 0   아니오  주 1회    True    False       False     31.0
# 1     예  월 1회    True    False        True     39.0
# 2     예  주 1회    True    False        True      NaN
# 3     예  안 마심    True    False        True     36.0
# 4   아니오  안 마심    True     True       False     42.0

# %%
data['흡연 여부'].value_counts()
# Out:
# 아니오    85468
# 예      21371
# Name: 흡연 여부, dtype: int64

# %%
# Write code here!

# %% [markdown]
# ** 14. 전체 데이터에서 유료 사용자와 무료 사용자의 인원의 총합을 찾아주세요. **
#
# 또한 유료 사용자만 한정해서, 3개월 / 6개월 / 12개월 결제자의 인원의 총합을 찾아주세요.

# %%
data['가입 개월 수'].value_counts()
# Out:
# True    74955
# 3개월     21250
# 6개월      7291
# 12개월     3343
# Name: 가입 개월 수, dtype: int64

# %%
# Write code here!

# %% [markdown]
# ** 15. 전체 데이터에서 흡연자와 음주 여부를 바탕으로 다음을 분석해주세요. **
#   1. 흡연과 음주를 둘 다 안 하는 사람의 인원 총합.
#   1. 흡연은 하지만 음주는 안 하는 사람의 인원 총합.
#   1. 흡연은 하지 않지만 음주는 하는 사람의 인원 총합.
#   1. 흡연과 음주를 둘 다 하는 사람의 인원 총합.

# %%
data.head()
# Out:
#     이름  성별           전화번호   나이 현재 체중 목표 체중    키         회원 가입일      회원 정보 갱신일  \
# 0  안원준  남성  010-2292-6251  31세    78    68  176  2016년 07월 05일  2016년 07월 05일
# 1  유세아  여성    01045795881   39    56    51  172  2016년 10월 02일  2016년 11월 29일
# 2  송솔은  여성  010-7719-8346  NaN   NaN   NaN  167  2017년 09월 06일  2017년 09월 06일
# 3  백서원  여성    01011947169   36    67    65    0  2017년 06월 02일  2017년 07월 28일
# 4  박서은  여성  010-2575-6398   42    60    57  167  2017년 05월 07일  2017년 05월 07일
#
#   흡연 여부 음주 여부 가입 개월 수  개인상담 요청 흡연 여부(bool)  나이(int)
# 0   아니오  주 1회    True    False       False     31.0
# 1     예  월 1회    True    False        True     39.0
# 2     예  주 1회    True    False        True      NaN
# 3     예  안 마심    True    False        True     36.0
# 4   아니오  안 마심    True     True       False     42.0

# %%
data.loc[data["흡연 여부"] == "아니오" & data["음주 여부"] == "안 마심", ]
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 106809    False
# 106810    False
# 106811    False
# 106812    False
# 106813    False
# 106814    False
# 106815    False
# 106816    False
# 106817    False
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# 106823    False
# 106824    False
# 106825    False
# 106826    False
# 106827     True
# 106828    False
# 106829    False
# 106830    False
# 106831    False
# 106832    False
# 106833    False
# 106834    False
# 106835    False
# 106836    False
# 106837    False
# 106838     True
# Name: 음주 여부, Length: 106839, dtype: bool

# %%
# Write code here!

# %% [markdown]
# ## 과제(중급)

# %% [markdown]
# ** 16. 성별 컬럼을 정리하기 **
#
# 성별 컬럼을 정리해주세요.
#
# 데이터를 분석해보면 남성, 여성, 남, 녀, Male, FEMALE 등의 다양한 표현이 있습니다. 이 표현을 male, female으로 통일해주세요.

# %%
# Write code here!

# %% [markdown]
# **17. 전체 인원이 아닌, 남성/여성 각각의 최소/평균/최대 키/몸무게/나이를 구해주세요.**
#
# 결과적으로 다음의 수치가 나와야 합니다.
#   * 전체 남성의 최소/평균/최대 나이
#   * 전체 남성의 최소/평균/최대 몸무게(kg)
#   * 전체 남성의 최소/평균/최대 키(cm)
#
#   * 전체 여성의 최소/평균/최대 나이
#   * 전체 여성의 최소/평균/최대 몸무게(kg)
#   * 전체 여성의 최소/평균/최대 키(cm)

# %%
# Write code here!

# %% [markdown]
# ** 18. 감량 목표를 분석하기 **
#
# 데이터에서 '현재 체중' - '목표 체중' 을 하면 감량 목표가 나올 것입니다. 감량 목표를 찾아서 새로운 컬럼을 만들어주세요.
#
# 또한 kg별로 감량을 원하는 사람의 총 인원을 구해주세요. 가령 1) 1kg 감량을 원하는 총 인원, 2) 2kg 감량을 원하는 총 인원, ... 10) 10kg 감량을 원하는 총 인원이 나와야 합니다.

# %%
# Write code here!

# %% [markdown]
# ** 19. '가입 개월 수'를 숫자로 표현하기 **
#
# '가입 개월 수' 컬럼을 숫자로 정리해주세요. 현재 3개월, 6개월, 12개월로 되어있는데, 이를 3, 6, 12로 정리하시면 됩니다.
#
# 또한 0개월은 0이 아닌 NaN으로 집어넣어 주세요.

# %%
# Write code here!

# %% [markdown]
# ** 20. '음주 여부'를 숫자로 표현하기**
#
# '음주 여부' 컬럼을 숫자로 정리해주세요. 현재 1) 주 2회, 2) 주 1회, 3) 월 2회, 4) 월 1회 5) 안 마심으로 되어 있습니다만, 이를 월 기준 음주 횟수로 통일해주세요. 여기서 월은 30일로, 주는 4주로 고정합니다.
#
# 가령 1) 주 2회는 8, 2) 주 1회는 4, 3) 월 2회는 2, 4) 월 1회는 1, 5) 안 마심은 0으로 표현하면 됩니다.

# %%
# Write code here!

# %% [markdown]
# ## 과제(고급)

# %% [markdown]
# ** 21.휴대폰 번호 정리하기 **
#
# 다양한 표현으로 되어있는 휴대폰 번호를 010-xxxx-xxxx 로 통일해주세요. 가령 휴대폰 번호에 하이픈이 없으면 넣어주시면 됩니다.
#
# 또한 unknown으로 되어있거나 비어있는 값은 NaN으로 처리해주세요.

# %%
# Write code here!

# %% [markdown]
# ** 22. 날짜를 사용 가능하게 정리하기 **
#
# 현재 '회원 가입일' 컬럼과 '회원 정보 갱신일' 컬럼은 20xx년 xx월 xx일 과 같은 형식으로 되어있습니다.
#
# 이 데이터를 현재 판다스에서는 날짜 컬럼이 아닌 문자열(텍스트) 컬럼으로 인식하고 있는데, 이 컬럼을 날짜 컬럼으로 인식할 수 있도록 수정해주세요.

# %%
# Write code here!

# %% [markdown]
# ** 23. 날짜를 기준으로 분석하기 **
#
# 22번에서 날짜 컬럼을 만들었으면 다음을 분석해주세요.
#
# 1. 월별 전체 회원 가입량
# 2. 월 별 유료/무료 회원 가입량의 차이
# 3. 월 별 남성/여성 회원 가입량의 차이

# %%
# Write code here!

# %% [markdown]
# ** 24. 회원 정보가 맞는지 여부를 확인하는 컬럼을 만들기 **
#
# 더 정확한 데이터 분석을 위해서는, 현재까지 고객님이 기업한 회원 정보가 정확한지를 확인하는 작업이 필요합니다. 분석팀에서 데이터를 다음과 같이 정리하면, 오퍼레이션 팀과 코칭 팀이 협업을 통해서 고객 정보를 개선하고, 더 좋은 서비스를 제공할 수 있을 것 같습니다. 다음의 내용이 담겨있는 새로운 컬럼을 하나 만들어주세요. 해당 컬럼에는 reject / counselling / duplicated / confirmed 라는 결과값이 들어가야 합니다.
#
# 다음의 경우에는 재기입을 요청한다. (reject)
# * 전화번호가 비어있는 경우
#
# 다음의 경우는 트레이너와 상담을 유도한다. (counselling)
# * 상담 요청(counselling)이 True인 사람.
#
# 다음의 경우에는 중복을 확인한다. (duplicated)
# * 동일한 이름에 동일한 전화번호를 찾아낸다. 이는 중복되었다고 가정한다.
#
# 나머지는 문제가 없다. (confirmed)

# %%
# Write code here!

# %% [markdown]
# **25. VIP 찾아내기**
#
# 다음의 고객을 특별 관리 대상으로 지정합니다. 특별 관리 대상이라고 함은, TKX 서비스의 VIP 플랜을 구매할 확률이 높은 분들을 의미합니다.
#
# 1. 트레이너와 상담을 요청한 사람. (counselling)
# 2. 상담을 요청하지 않은 사람 중, (현재 체중 - 목표 체중) 이 가장 높은 상위 1,000 명.
#
# 이 사람들을 특별관리 대상으로 지정하며, VIP라는 이름의 컬럼에 True 값을 넣으면 됩니다. 이후에는 오퍼레이션/코치 팀이 해당 고객님을 개별 컨택하여, 적극적으로 VIP 플랜을 구매하실 수 있도록 노력할 생각입니다. (특별관리 대상이 아닌 분들은 VIP 컬럼에 False 값을 넣으면 됩니다)
#
# 또한 전체 데이터와는 별개로, VIP 고객들만을 따로 뽑아내서 CSV파일로 저장할 수 있다면 좋겠습니다.

# %%
# Write code here!
